# %% [markdown]
# # Reload the predictions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import open_cp.scripted
import open_cp.scripted.analysis as analysis

# %%
betas = analysis.hit_counts_to_beta("north.csv")

# %%
fig, ax = plt.subplots(figsize=(12,8))
analysis.plot_betas(betas, ax)

# %%
fig, axes = plt.subplots(ncols=2, figsize=(16,8))
analysis.plot_betas(betas, axes[0], range(1,21))
analysis.plot_betas(betas, axes[1], range(1,21), False)

# %%
betas = analysis.hit_counts_to_beta("north1.csv")

# %%
fig, ax = plt.subplots(figsize=(12,8))
analysis.plot_betas(betas, ax)

# %%
fig, axes = plt.subplots(ncols=2, figsize=(16,8))
analysis.plot_betas(betas, axes[0], range(1,21))
analysis.plot_betas(betas, axes[1], range(1,21), False)

# %%
betas = analysis.hit_counts_to_beta("north2.csv")

# %%
fig, ax = plt.subplots(figsize=(12,8))
analysis.plot_betas(betas, ax)

# %%
fig, axes = plt.subplots(ncols=2, figsize=(16,8))
analysis.plot_betas(betas, axes[0], range(1,21))
analysis.plot_betas(betas, axes[1], range(1,21), False)

# %%
betas = analysis.hit_counts_to_beta("north3.csv")

# %%
fig, ax = plt.subplots(figsize=(12,8))
analysis.plot_betas(betas, ax)

# %%
fig, axes = plt.subplots(ncols=2, figsize=(16,8))
analysis.plot_betas(betas, axes[0], range(1,21))
analysis.plot_betas(betas, axes[1], range(1,21), False)
